# %% [markdown]
# # Importing Pacakges

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore") # It will ignore all the warnings that appear after you execute a code

# %% [markdown]
# # Data Pre Procising

# %%
data=pd.read_csv(r"C:\Users\Arigala.Adarsh\Downloads\bank-additional-full.csv",sep=';') # utf encoding

# %%
data.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (41199, 21)

# %%
data['y'].value_counts()
# Out:
# no     36556
# yes     4640
# Name: y, dtype: int64

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41195.000000  41196.000000  41196.000000  41196.000000  41196.000000
# mean      40.030319    258.281265      2.567676    962.482547      0.173124
# std       10.431818    259.254211      2.769751    186.893451      0.494987
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41196.000000    41195.000000   41196.000000  41196.000000  41196.000000
# mean       0.081656       93.575867     -40.504600      3.620787   5166.996405
# std        1.570894        0.578999       4.629972      1.734655     72.300104
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
data.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
#  17  cons.conf.idx   41196 non-null  float64
#  18  euribor3m       41196 non-null  float64
#  19  nr.employed     41196 non-null  float64
#  20  y               41196 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 6.6+ MB

# %%
data['y']
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41194     no
# 41195     no
# 41196     no
# 41197    NaN
# 41198     no
# Name: y, Length: 41199, dtype: object

# %%
data['job'].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1726
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
data['default'].value_counts()
# Out:
# no         32595
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
data['y'] = np.where(data['y'] == 'yes',1,0)  # I replaced yes -> 1, no -> 0
data['y'] = data['y'].astype(str)

# %%
data.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data['y'].tail()
# Out:
# 41194    0
# 41195    0
# 41196    0
# 41197    0
# 41198    0
# Name: y, dtype: object

# %%
data
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...       1.0  999.0       0.0
# 1      telephone   may         mon  ...       1.0  999.0       0.0
# 2      telephone   may         mon  ...       1.0  999.0       0.0
# 3      telephone   may         mon  ...       1.0  999.0       0.0
# 4      telephone   may         mon  ...       1.0  999.0       0.0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41194   cellular   nov         fri  ...       3.0  999.0       1.0
# 41195   cellular   nov         fri  ...       3.0  999.0       1.0
# 41196   cellular   nov         fri  ...       3.0  999.0       1.0
# 41197        NaN   NaN         NaN  ...       NaN    NaN       NaN
# 41198   cellular   nov         fri  ...       3.0  999.0       1.0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41194      failure         -1.1          94.767          -50.8      1.028
# 41195      failure         -1.1          94.767          -50.8      1.028
# 41196      failure         -1.1          94.767          -50.8      1.028
# 41197          NaN          NaN             NaN            NaN        NaN
# 41198      failure         -1.1             NaN          -50.8      1.028
#
#        nr.employed  y
# 0           5191.0  0
# 1           5191.0  0
# 2           5191.0  0
# 3           5191.0  0
# 4           5191.0  0
# ...            ... ..
# 41194       4963.6  0
# 41195       4963.6  0
# 41196       4963.6  0
# 41197          NaN  0
# 41198       4963.6  0
#
# [41199 rows x 21 columns]

# %%
data.isna()
# Out:
#          age    job  marital  education  default  housing   loan  contact  \
# 0      False  False    False      False    False    False  False    False
# 1      False  False    False      False    False    False  False    False
# 2      False  False    False      False    False    False  False    False
# 3      False  False    False      False    False    False  False    False
# 4      False  False    False      False    False    False  False    False
# ...      ...    ...      ...        ...      ...      ...    ...      ...
# 41194  False  False    False      False    False    False  False    False
# 41195  False   True    False      False    False    False  False    False
# 41196  False  False    False       True    False    False  False    False
# 41197   True   True     True       True     True     True   True     True
# 41198  False  False    False      False    False    False   True    False
#
#        month  day_of_week  ...  campaign  pdays  previous  poutcome  \
# 0      False        False  ...     False  False     False     False
# 1      False        False  ...     False  False     False     False
# 2      False        False  ...     False  False     False     False
# 3      False        False  ...     False  False     False     False
# 4      False        False  ...     False  False     False     False
# ...      ...          ...  ...       ...    ...       ...       ...
# 41194  False        False  ...     False  False     False     False
# 41195  False        False  ...     False  False     False     False
# 41196  False        False  ...     False  False     False     False
# 41197   True         True  ...      True   True      True      True
# 41198  False        False  ...     False  False     False     False
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 0             False           False          False      False        False
# 1             False           False          False      False        False
# 2             False           False          False      False        False
# 3             False           False          False      False        False
# 4             False           False          False      False        False
# ...             ...             ...            ...        ...          ...
# 41194         False           False          False      False        False
# 41195         False           False          False      False        False
# 41196         False           False          False      False        False
# 41197          True            True           True       True         True
# 41198         False            True          False      False        False
#
#            y
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 41194  False
# 41195  False
# 41196  False
# 41197  False
# 41198  False
#
# [41199 rows x 21 columns]

# %%
data.isna().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#                  age     job  marital          education default housing  \
# count   41195.000000   41194    41194              41194   41195   41196
# unique           NaN      12        4                  8       3       3
# top              NaN  admin.  married  university.degree      no     yes
# freq             NaN   10422    24934              12168   32595   21584
# mean       40.030319     NaN      NaN                NaN     NaN     NaN
# std        10.431818     NaN      NaN                NaN     NaN     NaN
# min        17.000000     NaN      NaN                NaN     NaN     NaN
# 25%        32.000000     NaN      NaN                NaN     NaN     NaN
# 50%        38.000000     NaN      NaN                NaN     NaN     NaN
# 75%        47.000000     NaN      NaN                NaN     NaN     NaN
# max        98.000000     NaN      NaN                NaN     NaN     NaN
#
#          loan   contact  month day_of_week  ...      campaign         pdays  \
# count   41195     41195  41196       41196  ...  41196.000000  41196.000000
# unique      3         2     10           5  ...           NaN           NaN
# top        no  cellular    may         thu  ...           NaN           NaN
# freq    33957     26151  13769        8623  ...           NaN           NaN
# mean      NaN       NaN    NaN         NaN  ...      2.567676    962.482547
# std       NaN       NaN    NaN         NaN  ...      2.769751    186.893451
# min       NaN       NaN    NaN         NaN  ...      1.000000      0.000000
# 25%       NaN       NaN    NaN         NaN  ...      1.000000    999.000000
# 50%       NaN       NaN    NaN         NaN  ...      2.000000    999.000000
# 75%       NaN       NaN    NaN         NaN  ...      3.000000    999.000000
# max       NaN       NaN    NaN         NaN  ...     56.000000    999.000000
#
#             previous     poutcome  emp.var.rate  cons.price.idx  \
# count   41196.000000        41194  41196.000000    41195.000000
# unique           NaN            3           NaN             NaN
# top              NaN  nonexistent           NaN             NaN
# freq             NaN        35563           NaN             NaN
# mean        0.173124          NaN      0.081656       93.575867
# std         0.494987          NaN      1.570894        0.578999
# min         0.000000          NaN     -3.400000       92.201000
# 25%         0.000000          NaN     -1.800000       93.075000
# 50%         0.000000          NaN      1.100000       93.749000
# 75%         0.000000          NaN      1.400000       93.994000
# max         7.000000          NaN      1.400000       94.767000
#
#         cons.conf.idx     euribor3m   nr.employed      y
# count    41196.000000  41196.000000  41196.000000  41199
# unique            NaN           NaN           NaN      2
# top               NaN           NaN           NaN      0
# freq              NaN           NaN           NaN  36559
# mean       -40.504600      3.620787   5166.996405    NaN
# std          4.629972      1.734655     72.300104    NaN
# min        -50.800000      0.634000   4963.600000    NaN
# 25%        -42.700000      1.344000   5099.100000    NaN
# 50%        -41.800000      4.857000   5191.000000    NaN
# 75%        -36.400000      4.961000   5228.100000    NaN
# max        -26.900000      5.045000   5228.100000    NaN
#
# [11 rows x 21 columns]

# %%
data['marital'].value_counts()
# Out:
# married     24934
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64

# %%
data['job'].mode()
# Out:
# 0    admin.
# Name: job, dtype: object

# %%
data.duplicated().sum()
data.drop_duplicates()
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41192  74.0    retired      NaN  professional.course      NaN     yes   no
# 41193  94.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...       1.0  999.0       0.0
# 1      telephone   may         mon  ...       1.0  999.0       0.0
# 2      telephone   may         mon  ...       1.0  999.0       0.0
# 3      telephone   may         mon  ...       1.0  999.0       0.0
# 4      telephone   may         mon  ...       1.0  999.0       0.0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41192   cellular   nov         fri  ...       3.0  999.0       1.0
# 41193   cellular   nov         fri  ...       3.0  999.0       1.0
# 41195   cellular   nov         fri  ...       3.0  999.0       1.0
# 41196   cellular   nov         fri  ...       3.0  999.0       1.0
# 41198   cellular   nov         fri  ...       3.0  999.0       1.0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41192      failure         -1.1          94.767          -50.8      1.028
# 41193      failure         -1.1          94.767          -50.8      1.028
# 41195      failure         -1.1          94.767          -50.8      1.028
# 41196      failure         -1.1          94.767          -50.8      1.028
# 41198      failure         -1.1             NaN          -50.8      1.028
#
#        nr.employed  y
# 0           5191.0  0
# 1           5191.0  0
# 2           5191.0  0
# 3           5191.0  0
# 4           5191.0  0
# ...            ... ..
# 41192       4963.6  0
# 41193       4963.6  0
# 41195       4963.6  0
# 41196       4963.6  0
# 41198       4963.6  0
#
# [41184 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
col=list(data.columns)
print(col)
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']

# %% [markdown]
# # Identifyfing Outliers

# %%
for i in col:
    if(data[i].dtype!='object'):
        plt.figure()
        sns.boxplot(data[i])

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41195.000000  41196.000000  41196.000000  41196.000000  41196.000000
# mean      40.030319    258.281265      2.567676    962.482547      0.173124
# std       10.431818    259.254211      2.769751    186.893451      0.494987
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41196.000000    41195.000000   41196.000000  41196.000000  41196.000000
# mean       0.081656       93.575867     -40.504600      3.620787   5166.996405
# std        1.570894        0.578999       4.629972      1.734655     72.300104
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
# Gerneralised formula
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
type(IQR)
# Out:
# age                15.000
# duration          217.000
# campaign            2.000
# pdays               0.000
# previous            0.000
# emp.var.rate        3.200
# cons.price.idx      0.919
# cons.conf.idx       6.300
# euribor3m           3.617
# nr.employed       129.000
# dtype: float64
# pandas.core.series.Series

# %%
col=list(data.columns)
print(col)
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']

# %%
for i in col:
    if(data[i].dtypes=='float64'):
        q1=data[i].quantile(0.25)
        q3=data[i].quantile(0.75)
        IQR=q3-q1
        data1=data[(data[i]>=(q1-1.5*IQR))&(data[i]<=(q3+1.5*IQR))]

# %%
 for col_name in col:
    if(data1[col_name].dtypes=='float64'):
        plt.boxplot(data1[col_name])
        plt.xlabel(col_name)
        plt.ylabel('count')
        plt.show()

# %%
data1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
data1.isnull().sum()
# Out:
# age               1
# job               2
# marital           2
# education         2
# default           1
# housing           0
# loan              1
# contact           1
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          2
# emp.var.rate      0
# cons.price.idx    1
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41196 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
#  17  cons.conf.idx   41196 non-null  float64
#  18  euribor3m       41196 non-null  float64
#  19  nr.employed     41196 non-null  float64
#  20  y               41196 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 6.9+ MB

# %%
data1.shape
# Out:
# (41196, 21)

# %%
data1.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
# 3          93.994          -36.4      4.857       5191.0  0
# 4          93.994          -36.4      4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (41199, 21)

# %%
data.isna().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 0
# dtype: int64

# %% [markdown]
# # Removing Outliers

# %%
data = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)] # axis = 1 --> column wise

# %%
 for col_name in col:
    if(data[col_name].dtypes=='float64'):
        plt.boxplot(data[col_name])
        plt.xlabel(col_name)
        plt.ylabel('count')
        plt.show()

# %%
data.shape
# Out:
# (35195, 21)

# %%
col=list(data.columns)
print(col)
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']

# %%
col.remove('y')

# %%
col
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
for i in col:
    if data[i].dtypes=='object':
        #print('ob')
        data[i] = data[i].fillna(data[i].mode()[0])
    else:
        #print('num')
        data[i] = data[i].fillna(data[i].mean())

# %%
data.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
# 3          93.994          -36.4      4.857       5191.0  0
# 4          93.994          -36.4      4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
data.age.unique()
# Out:
# array([56.        , 57.        , 37.        , 40.        , 45.        ,
#        59.        , 41.        , 24.        , 25.        , 29.        ,
#        35.        , 54.        , 46.        , 50.        , 39.        ,
#        30.        , 55.        , 49.        , 34.        , 58.        ,
#        32.        , 38.        , 44.        , 42.        , 60.        ,
#        53.        , 47.        , 48.        , 33.        , 51.        ,
#        31.        , 52.        , 43.        , 36.        , 28.        ,
#        27.        , 26.        , 22.        , 23.        , 20.        ,
#        21.        , 61.        , 19.        , 18.        , 70.        ,
#        66.        , 76.        , 67.        , 73.        , 88.        ,
#        95.        , 77.        , 68.        , 75.        , 63.        ,
#        80.        , 62.        , 65.        , 72.        , 82.        ,
#        64.        , 71.        , 69.        , 78.        , 85.        ,
#        79.        , 83.        , 81.        , 74.        , 17.        ,
#        87.        , 91.        , 86.        , 98.        , 94.        ,
#        84.        , 92.        , 89.        , 39.95950669])

# %%
data.age.value_counts()
# Out:
# 31.0    1686
# 32.0    1605
# 33.0    1590
# 36.0    1555
# 34.0    1513
#         ...
# 91.0       1
# 87.0       1
# 98.0       1
# 95.0       1
# 92.0       1
# Name: age, Length: 79, dtype: int64

# %%
data.age.min()
# Out:
# 17.0

# %%
data.age.max()
# Out:
# 98.0

# %% [markdown]
# # Bining Age Column

# %%
bins = [10, 25, 50, 100]
data['age'] = pd.cut(data['age'], bins)

# %%
data.head()
# Out:
#          age        job  marital    education  default housing loan  \
# 0  (50, 100]  housemaid  married     basic.4y       no      no   no
# 1  (50, 100]   services  married  high.school  unknown      no   no
# 2   (25, 50]   services  married  high.school       no     yes   no
# 3   (25, 50]     admin.  married     basic.6y       no      no   no
# 4  (50, 100]   services  married  high.school       no      no  yes
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 1  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 2  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 3  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 4  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          1.1          93.994          -36.4      4.857       5191.0  0
# 1          1.1          93.994          -36.4      4.857       5191.0  0
# 2          1.1          93.994          -36.4      4.857       5191.0  0
# 3          1.1          93.994          -36.4      4.857       5191.0  0
# 4          1.1          93.994          -36.4      4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
data.dtypes
# Out:
# age               category
# job                 object
# marital             object
# education           object
# default             object
# housing             object
# loan                object
# contact             object
# month               object
# day_of_week         object
# duration           float64
# campaign           float64
# pdays              float64
# previous           float64
# poutcome            object
# emp.var.rate       float64
# cons.price.idx     float64
# cons.conf.idx      float64
# euribor3m          float64
# nr.employed        float64
# y                   object
# dtype: object

# %%
data['age'] = data.age.astype(str)

# %%
data.dtypes
# Out:
# age                object
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data['age'].unique()
# Out:
# array(['(50, 100]', '(25, 50]', '(10, 25]'], dtype=object)

# %%
data['age'].nunique()
# Out:
# 3

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype == 'object') & (col != 'y') ):
        col_list.append(col)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %% [markdown]
# # Label Encoder Converting Stirng Columns into Categorical Onces

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in col_list:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    3        1          0        0        0     0        1      6
# 1        2    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        2    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41194    2    5        1          5        0        2     0        0      7
# 41195    2    0        1          5        0        2     0        0      7
# 41196    2    5        1          6        0        2     0        0      7
# 41197    1    0        1          6        0        2     0        0      6
# 41198    2    5        1          5        0        2     0        0      7
#
#        day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0                1  ...  1.000000  999.0  0.000000         1      1.100000
# 1                1  ...  1.000000  999.0  0.000000         1      1.100000
# 2                1  ...  1.000000  999.0  0.000000         1      1.100000
# 3                1  ...  1.000000  999.0  0.000000         1      1.100000
# 4                1  ...  1.000000  999.0  0.000000         1      1.100000
# ...            ...  ...       ...    ...       ...       ...           ...
# 41194            0  ...  3.000000  999.0  1.000000         0     -1.100000
# 41195            0  ...  3.000000  999.0  1.000000         0     -1.100000
# 41196            0  ...  3.000000  999.0  1.000000         0     -1.100000
# 41197            1  ...  2.613236  999.0  0.118266         1      0.165901
# 41198            0  ...  3.000000  999.0  1.000000         0     -1.100000
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0           93.994000     -36.400000    4.85700   5191.00000  0
# 1           93.994000     -36.400000    4.85700   5191.00000  0
# 2           93.994000     -36.400000    4.85700   5191.00000  0
# 3           93.994000     -36.400000    4.85700   5191.00000  0
# 4           93.994000     -36.400000    4.85700   5191.00000  0
# ...               ...            ...        ...          ... ..
# 41194       94.767000     -50.800000    1.02800   4963.60000  0
# 41195       94.767000     -50.800000    1.02800   4963.60000  0
# 41196       94.767000     -50.800000    1.02800   4963.60000  0
# 41197       93.583224     -40.554669    3.72429   5172.38548  0
# 41198       93.583224     -50.800000    1.02800   4963.60000  0
#
# [35195 rows x 21 columns]

# %%
data.dtypes
# Out:
# age                 int32
# job                 int32
# marital             int32
# education           int32
# default             int32
# housing             int32
# loan                int32
# contact             int32
# month               int32
# day_of_week         int32
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome            int32
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35195 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             35195 non-null  int32
#  1   job             35195 non-null  int32
#  2   marital         35195 non-null  int32
#  3   education       35195 non-null  int32
#  4   default         35195 non-null  int32
#  5   housing         35195 non-null  int32
#  6   loan            35195 non-null  int32
#  7   contact         35195 non-null  int32
#  8   month           35195 non-null  int32
#  9   day_of_week     35195 non-null  int32
#  10  duration        35195 non-null  float64
#  11  campaign        35195 non-null  float64
#  12  pdays           35195 non-null  float64
#  13  previous        35195 non-null  float64
#  14  poutcome        35195 non-null  int32
#  15  emp.var.rate    35195 non-null  float64
#  16  cons.price.idx  35195 non-null  float64
#  17  cons.conf.idx   35195 non-null  float64
#  18  euribor3m       35195 non-null  float64
#  19  nr.employed     35195 non-null  float64
#  20  y               35195 non-null  object
# dtypes: float64(9), int32(11), object(1)
# memory usage: 4.4+ MB

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %% [markdown]
# # Finding Variance and Removing Unnesscary columns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

# %%
X=data[col_list]
X
#independent
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    3        1          0        0        0     0        1      6
# 1        2    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        2    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41194    2    5        1          5        0        2     0        0      7
# 41195    2    0        1          5        0        2     0        0      7
# 41196    2    5        1          6        0        2     0        0      7
# 41197    1    0        1          6        0        2     0        0      6
# 41198    2    5        1          5        0        2     0        0      7
#
#        day_of_week    duration  campaign  pdays  previous  poutcome  \
# 0                1  261.000000  1.000000  999.0  0.000000         1
# 1                1  149.000000  1.000000  999.0  0.000000         1
# 2                1  226.000000  1.000000  999.0  0.000000         1
# 3                1  151.000000  1.000000  999.0  0.000000         1
# 4                1  307.000000  1.000000  999.0  0.000000         1
# ...            ...         ...       ...    ...       ...       ...
# 41194            0  239.000000  3.000000  999.0  1.000000         0
# 41195            0  239.000000  3.000000  999.0  1.000000         0
# 41196            0  239.000000  3.000000  999.0  1.000000         0
# 41197            1  183.528899  2.613236  999.0  0.118266         1
# 41198            0  239.000000  3.000000  999.0  1.000000         0
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0          1.100000       93.994000     -36.400000    4.85700   5191.00000
# 1          1.100000       93.994000     -36.400000    4.85700   5191.00000
# 2          1.100000       93.994000     -36.400000    4.85700   5191.00000
# 3          1.100000       93.994000     -36.400000    4.85700   5191.00000
# 4          1.100000       93.994000     -36.400000    4.85700   5191.00000
# ...             ...             ...            ...        ...          ...
# 41194     -1.100000       94.767000     -50.800000    1.02800   4963.60000
# 41195     -1.100000       94.767000     -50.800000    1.02800   4963.60000
# 41196     -1.100000       94.767000     -50.800000    1.02800   4963.60000
# 41197      0.165901       93.583224     -40.554669    3.72429   5172.38548
# 41198     -1.100000       93.583224     -50.800000    1.02800   4963.60000
#
# [35195 rows x 20 columns]

# %%
X.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
X.values
# Out:
# array([[ 2.00000000e+00,  3.00000000e+00,  1.00000000e+00, ...,
#         -3.64000000e+01,  4.85700000e+00,  5.19100000e+03],
#        [ 2.00000000e+00,  7.00000000e+00,  1.00000000e+00, ...,
#         -3.64000000e+01,  4.85700000e+00,  5.19100000e+03],
#        [ 1.00000000e+00,  7.00000000e+00,  1.00000000e+00, ...,
#         -3.64000000e+01,  4.85700000e+00,  5.19100000e+03],
#        ...,
#        [ 2.00000000e+00,  5.00000000e+00,  1.00000000e+00, ...,
#         -5.08000000e+01,  1.02800000e+00,  4.96360000e+03],
#        [ 1.00000000e+00,  0.00000000e+00,  1.00000000e+00, ...,
#         -4.05546687e+01,  3.72428984e+00,  5.17238548e+03],
#        [ 2.00000000e+00,  5.00000000e+00,  1.00000000e+00, ...,
#         -5.08000000e+01,  1.02800000e+00,  4.96360000e+03]])

# %%
vif_data = pd.DataFrame() # Creating a new data frame
vif_data["feature"] = X.columns # adding a column- feature which will contain all the column names
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]  
vif_data
# Out:
#            feature            VIF
# 0              age       1.112035
# 1              job       1.024009
# 2          marital       1.104151
# 3        education       1.092468
# 4          default       1.093471
# 5          housing       1.012605
# 6             loan       1.002978
# 7          contact       2.385148
# 8            month       1.868251
# 9      day_of_week       1.010577
# 10        duration       1.031535
# 11        campaign       1.053524
# 12           pdays  742751.819339
# 13        previous       8.471021
# 14        poutcome       8.544205
# 15    emp.var.rate      43.225161
# 16  cons.price.idx       9.242187
# 17   cons.conf.idx       3.643180
# 18       euribor3m      93.577616
# 19     nr.employed      39.485746

# %%
data=data.drop('pdays',axis=1)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
print(vif_data)
# Out:
#            feature           VIF
# 0              age      8.597228
# 1              job      2.113797
# 2          marital      5.177417
# 3        education      4.431545
# 4          default      1.393764
# 5          housing      2.211967
# 6             loan      1.208627
# 7          contact      3.035213
# 8            month      7.104543
# 9      day_of_week      3.068056
# 10        duration      3.551456
# 11        campaign      1.923394
# 12        previous      9.344591
# 13        poutcome     80.943656
# 14    emp.var.rate     40.641190
# 15  cons.price.idx  41711.870821
# 16   cons.conf.idx    138.732000
# 17       euribor3m    356.480581
# 18     nr.employed  47479.291857

# %%
data=data.drop('nr.employed',axis=1)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'y'],
#       dtype='object')

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
vif_data["VIF"] = [variance_inflation_factor(X.values, i)  for i in range(len(X.columns))] 
print(vif_data)
# Out:
#            feature         VIF
# 0              age    8.593911
# 1              job    2.113660
# 2          marital    5.177407
# 3        education    4.431535
# 4          default    1.391710
# 5          housing    2.211601
# 6             loan    1.208555
# 7          contact    2.484683
# 8            month    6.149818
# 9      day_of_week    3.067089
# 10        duration    3.537893
# 11        campaign    1.920792
# 12        previous    9.187134
# 13        poutcome   79.907977
# 14    emp.var.rate   25.895056
# 15  cons.price.idx  488.600192
# 16   cons.conf.idx  115.553625
# 17       euribor3m  154.807434

# %%
data=data.drop('cons.price.idx',axis=1)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.conf.idx', 'euribor3m', 'y'],
#       dtype='object')

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
print(vif_data)
# Out:
#           feature        VIF
# 0             age   8.268925
# 1             job   2.105614
# 2         marital   5.084494
# 3       education   4.372797
# 4         default   1.389928
# 5         housing   2.208254
# 6            loan   1.207809
# 7         contact   2.356476
# 8           month   6.031298
# 9     day_of_week   3.050526
# 10       duration   3.494166
# 11       campaign   1.916097
# 12       previous   6.647933
# 13       poutcome  57.543843
# 14   emp.var.rate  14.639063
# 15  cons.conf.idx  49.366001
# 16      euribor3m  78.176322

# %%
data=data.drop('euribor3m',axis=1)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.conf.idx', 'y'],
#       dtype='object')

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
print(vif_data)
# Out:
#           feature        VIF
# 0             age   7.892543
# 1             job   2.098190
# 2         marital   5.035952
# 3       education   4.271306
# 4         default   1.389767
# 5         housing   2.203993
# 6            loan   1.207386
# 7         contact   2.356368
# 8           month   5.412260
# 9     day_of_week   3.023580
# 10       duration   3.483739
# 11       campaign   1.916097
# 12       previous   5.699603
# 13       poutcome  45.483140
# 14   emp.var.rate   1.575877
# 15  cons.conf.idx  45.456764

# %%
data=data.drop('cons.conf.idx',axis=1)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'poutcome', 'emp.var.rate', 'y'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
col_list=[]
for col in data.columns:
    if((data[col].dtype!='object') & (col!='y')):
            col_list.append(col)

# %%
X=data[col_list]
vif_data=pd.DataFrame()
vif_data['features']=X.columns
vif_data["vif"]=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#         features        vif
# 0            age   7.716269
# 1            job   2.096950
# 2        marital   4.897931
# 3      education   4.261741
# 4        default   1.384885
# 5        housing   2.189101
# 6           loan   1.205203
# 7        contact   2.308188
# 8          month   5.255983
# 9    day_of_week   3.009127
# 10      duration   3.457171
# 11      campaign   1.890377
# 12      previous   3.193649
# 13      poutcome  21.437171
# 14  emp.var.rate   1.548217

# %%
data=data.drop('poutcome',axis=1)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'emp.var.rate', 'y'],
#       dtype='object')

# %%
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
print(vif_data)
# Out:
#          feature       VIF
# 0            age  5.606818
# 1            job  2.065852
# 2        marital  4.034306
# 3      education  3.899547
# 4        default  1.375198
# 5        housing  2.125086
# 6           loan  1.200370
# 7        contact  2.295508
# 8          month  4.867671
# 9    day_of_week  2.864374
# 10      duration  3.189813
# 11      campaign  1.820624
# 12      previous  1.307012
# 13  emp.var.rate  1.525413

# %%
vif_data.feature
# Out:
# 0              age
# 1              job
# 2          marital
# 3        education
# 4          default
# 5          housing
# 6             loan
# 7          contact
# 8            month
# 9      day_of_week
# 10        duration
# 11        campaign
# 12        previous
# 13    emp.var.rate
# Name: feature, dtype: object

# %%
Ind_Features = list(vif_data.feature)
Ind_Features
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'previous',
#  'emp.var.rate']

# %%
df_ind = data[Ind_Features]  # All the truly independent columns 
df_ind
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    3        1          0        0        0     0        1      6
# 1        2    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        2    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41194    2    5        1          5        0        2     0        0      7
# 41195    2    0        1          5        0        2     0        0      7
# 41196    2    5        1          6        0        2     0        0      7
# 41197    1    0        1          6        0        2     0        0      6
# 41198    2    5        1          5        0        2     0        0      7
#
#        day_of_week    duration  campaign  previous  emp.var.rate
# 0                1  261.000000  1.000000  0.000000      1.100000
# 1                1  149.000000  1.000000  0.000000      1.100000
# 2                1  226.000000  1.000000  0.000000      1.100000
# 3                1  151.000000  1.000000  0.000000      1.100000
# 4                1  307.000000  1.000000  0.000000      1.100000
# ...            ...         ...       ...       ...           ...
# 41194            0  239.000000  3.000000  1.000000     -1.100000
# 41195            0  239.000000  3.000000  1.000000     -1.100000
# 41196            0  239.000000  3.000000  1.000000     -1.100000
# 41197            1  183.528899  2.613236  0.118266      0.165901
# 41198            0  239.000000  3.000000  1.000000     -1.100000
#
# [35195 rows x 14 columns]

# %%
df_dep = data['y']
df_dep
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41194    0
# 41195    0
# 41196    0
# 41197    0
# 41198    0
# Name: y, Length: 35195, dtype: object

# %%
df_ind.dtypes
# Out:
# age               int32
# job               int32
# marital           int32
# education         int32
# default           int32
# housing           int32
# loan              int32
# contact           int32
# month             int32
# day_of_week       int32
# duration        float64
# campaign        float64
# previous        float64
# emp.var.rate    float64
# dtype: object

# %% [markdown]
# # Spliting Data into Train and Test Dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_ind, df_dep, test_size=0.25, random_state=100)
# random state --> Select the data based upon the pattern

# %%
x_train.head()
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 30156    0    0        2          3        0        0     0        0      0
# 5992     1    9        1          6        0        0     0        1      6
# 40696    1    4        2          6        0        0     0        0      9
# 27698    1    4        1          6        0        0     0        0      5
# 29520    1    0        2          3        0        2     0        0      0
#
#        day_of_week  duration  campaign  previous  emp.var.rate
# 30156            2     264.0       1.0       0.0          -1.8
# 5992             3     162.0       1.0       0.0           1.1
# 40696            1     303.0       2.0       0.0          -1.1
# 27698            1     116.0       1.0       0.0          -1.8
# 29520            1     133.0       1.0       0.0          -1.8

# %%
x_train.shape
# Out:
# (26396, 14)

# %%
x_test.shape
# Out:
# (8799, 14)

# %% [markdown]
# # Chossing the Model

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()

# %%
logisticRegr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
test_pred = logisticRegr.predict(x_test)

# %%
test_pred
# Out:
# array(['0', '0', '0', ..., '0', '0', '0'], dtype=object)

# %% [markdown]
# # Finding the Probability

# %%
pd.DataFrame(logisticRegr.predict_proba(x_test))
# Out:
#              0         1
# 0     0.997003  0.002997
# 1     0.833170  0.166830
# 2     0.983887  0.016113
# 3     0.993242  0.006758
# 4     0.985196  0.014804
# ...        ...       ...
# 8794  0.999320  0.000680
# 8795  0.996684  0.003316
# 8796  0.990460  0.009540
# 8797  0.999542  0.000458
# 8798  0.998195  0.001805
#
# [8799 rows x 2 columns]

# %% [markdown]
# # Evaluation the Model

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test,test_pred)
# Out:
# 0.9469257870212524

# %%
c1=confusion_matrix(y_test,test_pred)
c1
# Out:
# array([[8285,   64],
#        [ 403,   47]], dtype=int64)

# %%
# If the target variable is having a continous data --> regression models
# Linear Regresssion, Decision Tree Regressor, Random Forest Regressor, Naive Bayes Regressor, SVM Regressor
# If the target variable is having a categorical data --> Classification models
# Logistic Regression, Decision Tree Classifier, Random Forest Classifier, Naive Bayes Classifier, SVM Classifier

# %%
# Null values 
# dtype == object --> replace the null values with mode
# dtype == int/float --> replace the null values with mean/median
# If outliers are present --> Median
# If outliers are not present --> Mean
# 1  2  3  4  5  100
# mean = 115/6 --> 19.16
# 1 2 3 4 5
# mean = 15/5 --> 3

# %%
# Label encoding --> The object data is converted into numeric data
# the conversion values will be according to alphabetical order
# job --> 2, admin --> 0 , banker --> 1
# age 
# 10-25,  25-50,  50-100
#  0        1        2

# %%
# Multicollinerity --> When we compare the relationship of all the columns with all the other columns at once
# VIF --> Variance Inflation Factor
# VIF helps us to reduce the multicollinearity among the independent variables
# VIF = 1 --> Variables are not multicorrelated
# VIF < 6 --> vARIABLES ARE MODERATELY multicorrelated --> Accepted
# VIF = More than 6 --> Variables are highly correlated, and we drop those columns

# %%
"""
Predicted   P	N
                1  0
                y  n
Actual  1  Py 	TP	FP
        0 Nn  	FN	TN
          
          #Sensitivity=TP/TP+FN  # pREDICTION --> tRUE, 1
          #Specificity=TN/TN+FP    pREDICTION --> tRUE, 0
"""  # accuracy ---> (  TP+TN)/(Total)
# Out:
# '\nPredicted   P\tN\n                1  0\n                y  n\nActual  1  Py \tTP\tFN\n        0 Nn  \tFP\tTN\n          \n          #Sensitivity=TP/TP+FN  # pREDICTION --> tRUE, 1\n          #Specificity=TN/TN+FP    pREDICTION --> tRUE, 0\n'

# %%
# pRECISION(SESITIVITY) --> Correct prediction --> TP/TP+FP --> specificity
# Recall(Specificity) --> Only the actual positive predictions --> TP/TP+FN   --> Sensitivity
# F1-score --> Average of recall and precision
# Support --> The count of occurence
